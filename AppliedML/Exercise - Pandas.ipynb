# %% [markdown]
# # Exercise: Pandas

# %% [markdown]
# ## To get started we'll need __`numpy`__ and __`pandas`__

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Read the Consumer Complaints data file named __`data/Consumer_Complaints.csv`__ into a DataFrame

# %%
data = pd.read_csv('data/Consumer_Complaints.csv')
data
# Out:
#        Date received                  Product  \
# 0         03/12/2014                 Mortgage
# 1         10/01/2016         Credit reporting
# 2         10/17/2016            Consumer Loan
# 3         06/08/2014              Credit card
# 4         09/13/2014          Debt collection
# 5         11/13/2013                 Mortgage
# 6         06/16/2015          Debt collection
# 7         06/15/2015         Credit reporting
# 8         11/13/2015                 Mortgage
# 9         10/21/2014                 Mortgage
# 10        04/14/2017                 Mortgage
# 11        03/30/2012             Student loan
# 12        02/03/2016          Debt collection
# 13        01/07/2015         Credit reporting
# 14        03/15/2013              Credit card
# 15        07/18/2016         Credit reporting
# 16        02/17/2016          Debt collection
# 17        11/07/2014                 Mortgage
# 18        04/17/2015                 Mortgage
# 19        03/09/2016         Credit reporting
# 20        02/04/2015          Debt collection
# 21        03/17/2017  Bank account or service
# 22        03/08/2012                 Mortgage
# 23        03/27/2013                 Mortgage
# 24        02/25/2014          Debt collection
# 25        11/18/2016                 Mortgage
# 26        07/16/2015                 Mortgage
# 27        11/03/2015          Debt collection
# 28        08/09/2016         Credit reporting
# 29        04/27/2016                 Mortgage
# ...              ...                      ...
# 957612    11/13/2013              Credit card
# 957613    03/05/2016             Student loan
# 957614    07/28/2014                 Mortgage
# 957615    10/21/2015              Credit card
# 957616    05/05/2016             Student loan
# 957617    03/25/2014  Bank account or service
# 957618    08/17/2016                 Mortgage
# 957619    04/11/2014  Bank account or service
# 957620    01/26/2017          Debt collection
# 957621    11/15/2012                 Mortgage
# 957622    03/19/2017  Bank account or service
# 957623    12/01/2016          Debt collection
# 957624    02/27/2017          Debt collection
# 957625    09/07/2016  Bank account or service
# 957626    03/16/2017  Bank account or service
# 957627    03/23/2017  Bank account or service
# 957628    11/22/2016                 Mortgage
# 957629    01/18/2017          Debt collection
# 957630    04/28/2015                 Mortgage
# 957631    09/12/2012  Bank account or service
# 957632    09/17/2015              Credit card
# 957633    02/11/2014              Credit card
# 957634    11/09/2016          Debt collection
# 957635    01/22/2016  Bank account or service
# 957636    01/26/2017          Debt collection
# 957637    04/10/2017          Debt collection
# 957638    02/07/2017          Debt collection
# 957639    01/04/2017                 Mortgage
# 957640    09/28/2015          Debt collection
# 957641    08/19/2016          Debt collection
#
#                                    Sub-product  \
# 0                               Other mortgage
# 1                                          NaN
# 2                                 Vehicle loan
# 3                                          NaN
# 4                                  Credit card
# 5       Conventional adjustable mortgage (ARM)
# 6                                      Medical
# 7                                          NaN
# 8                               Other mortgage
# 9                  Conventional fixed mortgage
# 10                              Other mortgage
# 11                    Non-federal student loan
# 12       Other (i.e. phone, health club, etc.)
# 13                                         NaN
# 14                                         NaN
# 15                                         NaN
# 16                                 Credit card
# 17                 Conventional fixed mortgage
# 18                                FHA mortgage
# 19                                         NaN
# 20                                    Mortgage
# 21                            Checking account
# 22                              Other mortgage
# 23                 Conventional fixed mortgage
# 24       Other (i.e. phone, health club, etc.)
# 25                 Conventional fixed mortgage
# 26                 Conventional fixed mortgage
# 27                                     Medical
# 28                                         NaN
# 29                 Conventional fixed mortgage
# ...                                        ...
# 957612                                     NaN
# 957613                Non-federal student loan
# 957614             Conventional fixed mortgage
# 957615                                     NaN
# 957616          Federal student loan servicing
# 957617                        Checking account
# 957618             Conventional fixed mortgage
# 957619                        Checking account
# 957620   Other (i.e. phone, health club, etc.)
# 957621                          Other mortgage
# 957622              Other bank product/service
# 957623                                Mortgage
# 957624   Other (i.e. phone, health club, etc.)
# 957625              Other bank product/service
# 957626              Other bank product/service
# 957627                        Checking account
# 957628             Conventional fixed mortgage
# 957629   Other (i.e. phone, health club, etc.)
# 957630                          Other mortgage
# 957631                        Checking account
# 957632                                     NaN
# 957633                                     NaN
# 957634                                 Medical
# 957635                        Checking account
# 957636   Other (i.e. phone, health club, etc.)
# 957637                             Credit card
# 957638   Other (i.e. phone, health club, etc.)
# 957639             Conventional fixed mortgage
# 957640                Non-federal student loan
# 957641                             Payday loan
#
#                                            Issue  \
# 0       Loan modification,collection,foreclosure
# 1         Incorrect information on credit report
# 2                     Managing the loan or lease
# 3                                     Bankruptcy
# 4                          Communication tactics
# 5       Loan servicing, payments, escrow account
# 6            Improper contact or sharing of info
# 7       Credit reporting company's investigation
# 8       Loan modification,collection,foreclosure
# 9       Loan modification,collection,foreclosure
# 10      Loan modification,collection,foreclosure
# 11                            Repaying your loan
# 12               Disclosure verification of debt
# 13        Incorrect information on credit report
# 14                    Closing/Cancelling account
# 15        Incorrect information on credit report
# 16           Improper contact or sharing of info
# 17      Loan modification,collection,foreclosure
# 18      Application, originator, mortgage broker
# 19        Incorrect information on credit report
# 20         Cont'd attempts collect debt not owed
# 21      Making/receiving payments, sending money
# 22      Loan servicing, payments, escrow account
# 23      Loan servicing, payments, escrow account
# 24         Cont'd attempts collect debt not owed
# 25                  Settlement process and costs
# 26      Application, originator, mortgage broker
# 27               Disclosure verification of debt
# 28      Credit reporting company's investigation
# 29      Loan servicing, payments, escrow account
# ...                                          ...
# 957612                          Billing disputes
# 957613        Dealing with my lender or servicer
# 957614  Application, originator, mortgage broker
# 957615                         Billing statement
# 957616        Dealing with my lender or servicer
# 957617                 Using a debit or ATM card
# 957618              Settlement process and costs
# 957619                 Using a debit or ATM card
# 957620     Cont'd attempts collect debt not owed
# 957621  Loan servicing, payments, escrow account
# 957622                 Using a debit or ATM card
# 957623     Cont'd attempts collect debt not owed
# 957624           Disclosure verification of debt
# 957625                  Deposits and withdrawals
# 957626  Making/receiving payments, sending money
# 957627                  Deposits and withdrawals
# 957628  Loan modification,collection,foreclosure
# 957629                     Communication tactics
# 957630  Loan servicing, payments, escrow account
# 957631  Making/receiving payments, sending money
# 957632                                   Rewards
# 957633     Identity theft / Fraud / Embezzlement
# 957634        False statements or representation
# 957635                  Deposits and withdrawals
# 957636     Cont'd attempts collect debt not owed
# 957637     Cont'd attempts collect debt not owed
# 957638     Cont'd attempts collect debt not owed
# 957639  Application, originator, mortgage broker
# 957640           Disclosure verification of debt
# 957641     Cont'd attempts collect debt not owed
#
#                                      Sub-issue  \
# 0                                          NaN
# 1                               Account status
# 2                                          NaN
# 3                                          NaN
# 4                   Frequent or repeated calls
# 5                                          NaN
# 6        Contacted employer after asked not to
# 7               Inadequate help over the phone
# 8                                          NaN
# 9                                          NaN
# 10                                         NaN
# 11                                         NaN
# 12        Not given enough info to verify debt
# 13                              Account status
# 14                                         NaN
# 15                              Account status
# 16       Talked to a third party about my debt
# 17                                         NaN
# 18                                         NaN
# 19                     Information is not mine
# 20                               Debt was paid
# 21                                         NaN
# 22                                         NaN
# 23                                         NaN
# 24                            Debt is not mine
# 25                                         NaN
# 26                                         NaN
# 27        Right to dispute notice not received
# 28           Problem with statement of dispute
# 29                                         NaN
# ...                                        ...
# 957612                                     NaN
# 957613        Keep getting calls about my loan
# 957614                                     NaN
# 957615                                     NaN
# 957616   Trouble with how payments are handled
# 957617                                     NaN
# 957618                                     NaN
# 957619                                     NaN
# 957620       Debt resulted from identity theft
# 957621                                     NaN
# 957622                                     NaN
# 957623       Debt was discharged in bankruptcy
# 957624  Not disclosed as an attempt to collect
# 957625                                     NaN
# 957626                                     NaN
# 957627                                     NaN
# 957628                                     NaN
# 957629   Used obscene/profane/abusive language
# 957630                                     NaN
# 957631                                     NaN
# 957632                                     NaN
# 957633                                     NaN
# 957634       Attempted to collect wrong amount
# 957635                                     NaN
# 957636                        Debt is not mine
# 957637                        Debt is not mine
# 957638                        Debt is not mine
# 957639                                     NaN
# 957640    Not given enough info to verify debt
# 957641                        Debt is not mine
#
#                              Consumer complaint narrative  \
# 0                                                     NaN
# 1       I have outdated information on my credit repor...
# 2       I purchased a new car on XXXX XXXX. The car de...
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# 6                                                     NaN
# 7       An account on my credit report has a mistaken ...
# 8                                                     NaN
# 9                                                     NaN
# 10                                                    NaN
# 11                                                    NaN
# 12      This company refuses to provide me verificatio...
# 13                                                    NaN
# 14                                                    NaN
# 15                                                    NaN
# 16      This complaint is in regards to Square Two Fin...
# 17                                                    NaN
# 18                                                    NaN
# 19                                                    NaN
# 20                                                    NaN
# 21                                                    NaN
# 22                                                    NaN
# 23                                                    NaN
# 24                                                    NaN
# 25      Started the refinance of home mortgage process...
# 26      In XXXX, I and my ex-husband applied for a ref...
# 27                                                    NaN
# 28      I have disputed several accounts on my credit ...
# 29      Mortgage was transferred to Nationstar as of X...
# ...                                                   ...
# 957612                                                NaN
# 957613                                                NaN
# 957614                                                NaN
# 957615                                                NaN
# 957616  ECSI XXXX., based in XXXX, PA, services my XXX...
# 957617                                                NaN
# 957618  I have a mortgage with Caliber Home Loans ( Ac...
# 957619                                                NaN
# 957620                                                NaN
# 957621                                                NaN
# 957622  My credit report is being negatively affected ...
# 957623                                                NaN
# 957624  I have never had XXXX billing, and do not owe ...
# 957625                                                NaN
# 957626                                                NaN
# 957627                                                NaN
# 957628                                                NaN
# 957629                                                NaN
# 957630                                                NaN
# 957631                                                NaN
# 957632  Barclay closed my Barclay XXXX MasterCard acco...
# 957633                                                NaN
# 957634  Our son was taken to XXXX XXXX XXXX XXXX XXXX ...
# 957635  On XXXX/XXXX/13, without my authorization, Ban...
# 957636                                                NaN
# 957637                                                NaN
# 957638  I had an account with XXXX in XX/XX/XXXX this ...
# 957639  I was contacted on XX/XX/XXXX email by XXXX fr...
# 957640                                                NaN
# 957641  I had a debit that was included in my chapter ...
#
#                                   Company public response  \
# 0                                                     NaN
# 1       Company has responded to the consumer and the ...
# 2                                                     NaN
# 3                                                     NaN
# 4                                                     NaN
# 5                                                     NaN
# 6       Company believes it acted appropriately as aut...
# 7        Company chooses not to provide a public response
# 8       Company believes it acted appropriately as aut...
# 9                                                     NaN
# 10      Company believes it acted appropriately as aut...
# 11                                                    NaN
# 12                                                    NaN
# 13                                                    NaN
# 14                                                    NaN
# 15                                                    NaN
# 16      Company has responded to the consumer and the ...
# 17                                                    NaN
# 18                                                    NaN
# 19      Company has responded to the consumer and the ...
# 20                                                    NaN
# 21      Company believes it acted appropriately as aut...
# 22                                                    NaN
# 23                                                    NaN
# 24                                                    NaN
# 25                                                    NaN
# 26                                                    NaN
# 27       Company chooses not to provide a public response
# 28                                                    NaN
# 29                                                    NaN
# ...                                                   ...
# 957612                                                NaN
# 957613                                                NaN
# 957614                                                NaN
# 957615   Company chooses not to provide a public response
# 957616                                                NaN
# 957617                                                NaN
# 957618                                                NaN
# 957619                                                NaN
# 957620  Company believes it acted appropriately as aut...
# 957621                                                NaN
# 957622  Company has responded to the consumer and the ...
# 957623  Company can't verify or dispute the facts in t...
# 957624  Company believes it acted appropriately as aut...
# 957625  Company has responded to the consumer and the ...
# 957626  Company has responded to the consumer and the ...
# 957627  Company has responded to the consumer and the ...
# 957628  Company has responded to the consumer and the ...
# 957629  Company has responded to the consumer and the ...
# 957630                                                NaN
# 957631                                                NaN
# 957632   Company chooses not to provide a public response
# 957633                                                NaN
# 957634  Company believes complaint caused principally ...
# 957635   Company chooses not to provide a public response
# 957636                                                NaN
# 957637  Company has responded to the consumer and the ...
# 957638  Company believes it acted appropriately as aut...
# 957639                                                NaN
# 957640   Company chooses not to provide a public response
# 957641  Company believes it acted appropriately as aut...
#
#                                        Company State ZIP code            Tags  \
# 0                         M&T BANK CORPORATION    MI    48382             NaN
# 1       TRANSUNION INTERMEDIATE HOLDINGS, INC.    AL    352XX             NaN
# 2               CITIZENS FINANCIAL GROUP, INC.    PA    177XX  Older American
# 3                     AMERICAN EXPRESS COMPANY    ID    83854  Older American
# 4                               CITIBANK, N.A.    VA    23233             NaN
# 5                                 U.S. BANCORP    MN    48322             NaN
# 6                  California Accounts Service    CA    92111             NaN
# 7          Experian Information Solutions Inc.    VA    224XX             NaN
# 8                           Aldridge Pite, LLP    CA    93101             NaN
# 9                     OCWEN LOAN SERVICING LLC    FL    32714  Older American
# 10                    Shellpoint Partners, LLC    CA    90305             NaN
# 11            Student Loan Finance Corporation    MN    55428             NaN
# 12                         The CBE Group, Inc.    TX    752XX             NaN
# 13         Experian Information Solutions Inc.    NV    89169             NaN
# 14                FIRST NATIONAL BANK OF OMAHA    NY    11732             NaN
# 15                               EQUIFAX, INC.    FL    33629             NaN
# 16             SQUARETWO FINANCIAL CORPORATION    NE    693XX             NaN
# 17                                U.S. BANCORP    MT    59801             NaN
# 18                       WELLS FARGO & COMPANY    ME    04032             NaN
# 19         Experian Information Solutions Inc.    CA    92703             NaN
# 20           PHH Mortgage Services Corporation    CA    92021             NaN
# 21      UNITED SERVICES AUTOMOBILE ASSOCIATION    WI    54005             NaN
# 22                        Ditech Financial LLC    CA    95361             NaN
# 23                         NATIONSTAR MORTGAGE    WA    98203             NaN
# 24                     Navient Solutions, LLC.    RI    02906             NaN
# 25              AMERICAN NEIGHBORHOOD MORTGAGE    NJ    088XX             NaN
# 26            HSBC NORTH AMERICA HOLDINGS INC.    IL    625XX             NaN
# 27                Revenue Recovery Corporation    FL    34105             NaN
# 28                               EQUIFAX, INC.    MS    390XX             NaN
# 29                         NATIONSTAR MORTGAGE    CA    954XX             NaN
# ...                                        ...   ...      ...             ...
# 957612                          CITIBANK, N.A.    IL    61568   Servicemember
# 957613                 Navient Solutions, LLC.    PR    00738             NaN
# 957614            FIRST GUARANTY MORTGAGE CORP    MD    20603             NaN
# 957615                          CITIBANK, N.A.    CO    81631             NaN
# 957616           HEARTLAND PAYMENT SYSTEMS INC    CA    934XX             NaN
# 957617    SANTANDER BANK, NATIONAL ASSOCIATION    MA    01952             NaN
# 957618                Caliber Home Loans, Inc.    TX    774XX             NaN
# 957619                          CITIBANK, N.A.    NY    10591             NaN
# 957620                                     ERC    IL    60073             NaN
# 957621   BANK OF AMERICA, NATIONAL ASSOCIATION    MA    01028             NaN
# 957622                        BB&T CORPORATION    TX    752XX             NaN
# 957623                    Ditech Financial LLC    AZ    85383             NaN
# 957624                                     ERC    NY    136XX             NaN
# 957625   BANK OF AMERICA, NATIONAL ASSOCIATION    NY    11372             NaN
# 957626   BANK OF AMERICA, NATIONAL ASSOCIATION    OH    43207             NaN
# 957627   BANK OF AMERICA, NATIONAL ASSOCIATION    IL    60634             NaN
# 957628                FREEDOM MORTGAGE COMPANY    MS    39560   Servicemember
# 957629                       I.C. System, Inc.    TX    75181             NaN
# 957630                Lynx Asset Services, LLC    NJ    08555             NaN
# 957631      BBVA COMPASS FINANCIAL CORPORATION    FL    34786             NaN
# 957632                  BARCLAYS BANK DELAWARE    IN    461XX             NaN
# 957633       CAPITAL ONE FINANCIAL CORPORATION    WV    25504  Older American
# 957634           R & B Corporation of Virginia    NJ    077XX             NaN
# 957635   BANK OF AMERICA, NATIONAL ASSOCIATION    FL    347XX             NaN
# 957636                 North Shore Agency, LLC    OR    97355             NaN
# 957637           PENTAGON FEDERAL CREDIT UNION    TX    77802             NaN
# 957638                                     ERC    NY    115XX   Servicemember
# 957639                Caliber Home Loans, Inc.    FL    336XX             NaN
# 957640    Progressive Financial Services, Inc.    OH    44017             NaN
# 957641                Midwest Recovery Systems    FL    336XX             NaN
#
#        Consumer consent provided? Submitted via Date sent to company  \
# 0                             NaN      Referral           03/17/2014
# 1                Consent provided           Web           10/05/2016
# 2                Consent provided           Web           10/20/2016
# 3                             NaN           Web           06/10/2014
# 4                             NaN           Web           09/13/2014
# 5                             NaN         Phone           11/20/2013
# 6            Consent not provided           Web           06/19/2015
# 7                Consent provided           Web           06/15/2015
# 8                             NaN      Referral           12/10/2015
# 9                             NaN           Web           10/21/2014
# 10                            NaN      Referral           04/14/2017
# 11                            NaN           Web           07/12/2012
# 12               Consent provided           Web           02/03/2016
# 13                            NaN      Referral           01/23/2015
# 14                            NaN      Referral           03/18/2013
# 15                            NaN           Fax           07/19/2016
# 16               Consent provided           Web           03/04/2016
# 17                            NaN           Web           11/07/2014
# 18           Consent not provided           Web           04/17/2015
# 19                            NaN         Phone           03/09/2016
# 20                            NaN           Web           02/10/2015
# 21                            NaN      Referral           03/20/2017
# 22                            NaN           Web           03/23/2012
# 23                            NaN           Web           03/27/2013
# 24                            NaN           Web           02/24/2014
# 25               Consent provided           Web           11/21/2016
# 26               Consent provided           Web           07/16/2015
# 27                            NaN   Postal mail           11/04/2015
# 28               Consent provided           Web           08/09/2016
# 29               Consent provided           Web           04/27/2016
# ...                           ...           ...                  ...
# 957612                        NaN           Web           11/12/2013
# 957613       Consent not provided           Web           03/08/2016
# 957614                        NaN           Web           07/28/2014
# 957615                        NaN      Referral           10/23/2015
# 957616           Consent provided           Web           05/09/2016
# 957617                        NaN           Web           03/25/2014
# 957618           Consent provided           Web           08/17/2016
# 957619                        NaN      Referral           04/16/2014
# 957620       Consent not provided           Web           01/26/2017
# 957621                        NaN      Referral           11/19/2012
# 957622           Consent provided           Web           03/19/2017
# 957623                        NaN      Referral           12/01/2016
# 957624           Consent provided           Web           02/27/2017
# 957625                        NaN      Referral           09/12/2016
# 957626                        NaN           Fax           03/30/2017
# 957627       Consent not provided           Web           03/23/2017
# 957628                        NaN         Phone           11/22/2016
# 957629       Consent not provided           Web           01/19/2017
# 957630                        NaN      Referral           05/01/2015
# 957631                        NaN      Referral           09/13/2012
# 957632           Consent provided           Web           09/17/2015
# 957633                        NaN           Web           02/11/2014
# 957634           Consent provided           Web           11/09/2016
# 957635           Consent provided           Web           01/22/2016
# 957636                        NaN      Referral           01/31/2017
# 957637                        NaN      Referral           04/11/2017
# 957638           Consent provided           Web           02/07/2017
# 957639           Consent provided           Web           01/04/2017
# 957640                        NaN   Postal mail           09/30/2015
# 957641           Consent provided           Web           08/19/2016
#
#        Company response to consumer Timely response? Consumer disputed?  \
# 0           Closed with explanation              Yes                 No
# 1           Closed with explanation              Yes                 No
# 2           Closed with explanation              Yes                 No
# 3           Closed with explanation              Yes                Yes
# 4           Closed with explanation              Yes                Yes
# 5       Closed with monetary relief              Yes                 No
# 6           Closed with explanation              Yes                 No
# 7           Closed with explanation              Yes                 No
# 8           Closed with explanation              Yes                Yes
# 9           Closed with explanation              Yes                 No
# 10          Closed with explanation              Yes                 No
# 11          Closed with explanation              Yes                 No
# 12          Closed with explanation              Yes                Yes
# 13          Closed with explanation              Yes                Yes
# 14          Closed with explanation              Yes                 No
# 15          Closed with explanation              Yes                 No
# 16          Closed with explanation              Yes                Yes
# 17          Closed with explanation              Yes                 No
# 18          Closed with explanation              Yes                 No
# 19          Closed with explanation              Yes                 No
# 20          Closed with explanation              Yes                Yes
# 21          Closed with explanation              Yes                 No
# 22            Closed without relief              Yes                 No
# 23          Closed with explanation              Yes                 No
# 24          Closed with explanation              Yes                Yes
# 25      Closed with monetary relief               No                 No
# 26          Closed with explanation              Yes                 No
# 27          Closed with explanation              Yes                 No
# 28          Closed with explanation              Yes                Yes
# 29          Closed with explanation              Yes                Yes
# ...                             ...              ...                ...
# 957612  Closed with monetary relief              Yes                 No
# 957613  Closed with monetary relief              Yes                 No
# 957614  Closed with monetary relief              Yes                 No
# 957615  Closed with monetary relief              Yes                 No
# 957616      Closed with explanation              Yes                 No
# 957617  Closed with monetary relief              Yes                 No
# 957618      Closed with explanation              Yes                Yes
# 957619  Closed with monetary relief              Yes                 No
# 957620                       Closed              Yes                 No
# 957621  Closed with monetary relief              Yes                 No
# 957622      Closed with explanation              Yes                 No
# 957623      Closed with explanation              Yes                 No
# 957624                       Closed              Yes                Yes
# 957625  Closed with monetary relief              Yes                 No
# 957626      Closed with explanation              Yes                 No
# 957627      Closed with explanation              Yes                 No
# 957628      Closed with explanation              Yes                Yes
# 957629      Closed with explanation              Yes                 No
# 957630      Closed with explanation              Yes                Yes
# 957631  Closed with monetary relief              Yes                 No
# 957632  Closed with monetary relief              Yes                 No
# 957633  Closed with monetary relief              Yes                 No
# 957634      Closed with explanation              Yes                 No
# 957635  Closed with monetary relief              Yes                 No
# 957636      Closed with explanation              Yes                 No
# 957637      Closed with explanation              Yes                 No
# 957638                       Closed              Yes                 No
# 957639      Closed with explanation              Yes                 No
# 957640      Closed with explanation              Yes                 No
# 957641      Closed with explanation              Yes                Yes
#
#         Complaint ID
# 0             759217
# 1            2141773
# 2            2163100
# 3             885638
# 4            1027760
# 5             596562
# 6            1422680
# 7            1420702
# 8            1654890
# 9            1079567
# 10           2436165
# 11             42864
# 12           1772196
# 13           1184859
# 14            357186
# 15           2017178
# 16           1790634
# 17           1107428
# 18           1334421
# 19           1823789
# 20           1224106
# 21           2393048
# 22             32412
# 23            366548
# 24            730165
# 25           2216206
# 26           1472017
# 27           1637385
# 28           2051099
# 29           1898476
# ...              ...
# 957612        595723
# 957613       1817381
# 957614        955942
# 957615       1618142
# 957616       1912906
# 957617        776970
# 957618       2069434
# 957619        805874
# 957620       2313827
# 957621        192117
# 957622       2393820
# 957623       2231005
# 957624       2361759
# 957625       2099790
# 957626       2391539
# 957627       2402119
# 957628       2219420
# 957629       2295668
# 957630       1350374
# 957631        150106
# 957632       1568426
# 957633        710260
# 957634       2201681
# 957635       1753439
# 957636       2313821
# 957637       2428130
# 957638       2331270
# 957639       2274241
# 957640       1582525
# 957641       2073214
#
# [957642 rows x 18 columns]

# %% [markdown]
# ## Determine the shape of the DataFrame

# %%
data.shape
# Out:
# (957642, 18)

# %% [markdown]
# ## Investigate the first few rows of the DataFrame and find out what columns are present

# %%
data.head()
# Out:
#   Date received           Product     Sub-product  \
# 0    03/12/2014          Mortgage  Other mortgage
# 1    10/01/2016  Credit reporting             NaN
# 2    10/17/2016     Consumer Loan    Vehicle loan
# 3    06/08/2014       Credit card             NaN
# 4    09/13/2014   Debt collection     Credit card
#
#                                       Issue                   Sub-issue  \
# 0  Loan modification,collection,foreclosure                         NaN
# 1    Incorrect information on credit report              Account status
# 2                Managing the loan or lease                         NaN
# 3                                Bankruptcy                         NaN
# 4                     Communication tactics  Frequent or repeated calls
#
#                         Consumer complaint narrative  \
# 0                                                NaN
# 1  I have outdated information on my credit repor...
# 2  I purchased a new car on XXXX XXXX. The car de...
# 3                                                NaN
# 4                                                NaN
#
#                              Company public response  \
# 0                                                NaN
# 1  Company has responded to the consumer and the ...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#                                   Company State ZIP code            Tags  \
# 0                    M&T BANK CORPORATION    MI    48382             NaN
# 1  TRANSUNION INTERMEDIATE HOLDINGS, INC.    AL    352XX             NaN
# 2          CITIZENS FINANCIAL GROUP, INC.    PA    177XX  Older American
# 3                AMERICAN EXPRESS COMPANY    ID    83854  Older American
# 4                          CITIBANK, N.A.    VA    23233             NaN
#
#   Consumer consent provided? Submitted via Date sent to company  \
# 0                        NaN      Referral           03/17/2014
# 1           Consent provided           Web           10/05/2016
# 2           Consent provided           Web           10/20/2016
# 3                        NaN           Web           06/10/2014
# 4                        NaN           Web           09/13/2014
#
#   Company response to consumer Timely response? Consumer disputed?  \
# 0      Closed with explanation              Yes                 No
# 1      Closed with explanation              Yes                 No
# 2      Closed with explanation              Yes                 No
# 3      Closed with explanation              Yes                Yes
# 4      Closed with explanation              Yes                Yes
#
#    Complaint ID
# 0        759217
# 1       2141773
# 2       2163100
# 3        885638
# 4       1027760

# %% [markdown]
# ## How many consumer complaints are there per state?

# %%
data['State'].value_counts()
# Out:
# CA    135002
# FL     91133
# TX     76955
# NY     64340
# GA     47759
# NJ     36870
# IL     35988
# PA     33399
# VA     29547
# MD     29070
# OH     29029
# NC     28458
# MI     23307
# AZ     21077
# WA     19482
# MA     17921
# CO     16159
# TN     15388
# SC     13350
# MO     12863
# NV     11734
# CT     11089
# IN     10977
# LA     10771
# OR     10660
# MN     10601
# AL     10541
# WI     10175
# KY      6951
# OK      6237
#        ...
# MS      4957
# DE      4841
# KS      4739
# NM      4512
# AR      4347
# NH      4035
# IA      3992
# ID      3076
# HI      3038
# ME      2983
# RI      2903
# NE      2901
# PR      2453
# WV      2424
# MT      1529
# VT      1433
# SD      1268
# AK      1056
# ND       951
# WY       869
# AE       388
# AP       271
# VI       200
# GU       152
# FM        48
# MP        31
# MH        30
# AS        25
# AA        19
# PW        13
# Name: State, Length: 62, dtype: int64

# %% [markdown]
# ## Which ZIP code has the highest number of complaints?

# %%
data['ZIP code'].value_counts()
# Out:
# 300XX    4887
# 770XX    3705
# 750XX    3301
# 606XX    3099
# 331XX    2857
# 330XX    2847
# 900XX    2658
# 945XX    2583
# 303XX    2542
# 334XX    2486
# 112XX    2201
# 302XX    2155
# 207XX    2120
# 891XX    2111
# 191XX    2034
# 100XX    2001
# 070XX    1959
# 752XX    1927
# 301XX    1790
# 926XX    1777
# 604XX    1737
# 852XX    1710
# 921XX    1706
# 333XX    1667
# 917XX    1665
# 282XX    1640
# 913XX    1585
# 322XX    1559
# 200XX    1555
# 782XX    1519
#          ...
# 98213       1
# 71001       1
# 10652       1
# 88301       1
# 16067       1
# 93603       1
# 39745       1
# 35815       1
# 12169       1
# 39109       1
# 3343-       1
# 97050       1
# 97296       1
# 75130       1
# 28640       1
# 79371       1
# 95187       1
# 75682       1
# 36263       1
# 29633       1
# 05072       1
# 32263       1
# 00270       1
# 97806       1
# 72530       1
# 26448       1
# 28758       1
# 95344       1
# 14061       1
# 27973       1
# Name: ZIP code, Length: 28758, dtype: int64

# %% [markdown]
# ## What are the top five products for complaints?

# %%
data['Product'].value_counts()[:5]
# Out:
# Mortgage                   247626
# Debt collection            182186
# Credit reporting           140433
# Credit card                 89191
# Bank account or service     86206
# Name: Product, dtype: int64

# %% [markdown]
# ## What are the top five states for consumer complaints?

# %%
data['State'].value_counts()[:5]
# Out:
# CA    135002
# FL     91133
# TX     76955
# NY     64340
# GA     47759
# Name: State, dtype: int64

# %% [markdown]
# ## What is potentially misleading about these results?
# * We can solve this problem by normalizing the results against population data.
# * Our complaints database doesn't have this information though, so, let's read the information from the file __`data/states.csv`__ into a DataFrame

# %%
states = pd.read_csv('data/states.csv')

# %% [markdown]
# ## Investigate the first few rows of the DataFrame

# %%
states.head()
# Out:
#             State Abbrev  Count  Population
# 0         Alabama     AL    129   4874747.0
# 1          Alaska     AK     35    739795.0
# 2  American Samoa     AS      1     51504.0
# 3        Arizona      AZ    155   7016270.0
# 4        Arkansas     AR    108   3004279.0

# %% [markdown]
# ## The __`Count`__ column is irrelevant, so...
# * Create a new DataFrame with only the 'Abbrev' and 'Population' columns

# %%
states = states[['Abbrev', 'Population']]
states
# Out:
#    Abbrev  Population
# 0      AL   4874747.0
# 1      AK    739795.0
# 2      AS     51504.0
# 3      AZ   7016270.0
# 4      AR   3004279.0
# 5      CA  39536653.0
# 6      CO   5607154.0
# 7      CT   3588184.0
# 8      DE    961939.0
# 9      DC    693972.0
# 10     FM         NaN
# 11     FL  20984400.0
# 12     GA  10429379.0
# 13     GU    167358.0
# 14     HI   1427538.0
# 15     ID   1716943.0
# 16     IL  12802023.0
# 17     IN   6666818.0
# 18     IA   3145711.0
# 19     KS   2913123.0
# 20     KY   4454189.0
# 21     LA   4684333.0
# 22     ME   1335907.0
# 23     MH         NaN
# 24     MD   6052177.0
# 25     MA   6859819.0
# 26     MI   9962311.0
# 27     MN   5576606.0
# 28     MS   2984100.0
# 29     MO   6113532.0
# 30     MT   1050493.0
# 31     NE   1920076.0
# 32     NV   2998039.0
# 33     NH   1342795.0
# 34     NJ   9005644.0
# 35     NM   2088070.0
# 36     NY  19849399.0
# 37     NC  10273419.0
# 38     ND    755393.0
# 39     MP         NaN
# 40     OH  11658609.0
# 41     OK   3930864.0
# 42     OR   4142776.0
# 43     PW         NaN
# 44     PA  12805537.0
# 45     PR   3337177.0
# 46     RI   1059639.0
# 47     SC   5024369.0
# 48     SD    869666.0
# 49     TN   6715984.0
# 50     TX  28304596.0
# 51     UT   3101833.0
# 52     VT    623657.0
# 53     VI         NaN
# 54     VA   8470020.0
# 55     WA   7405743.0
# 56     WV   1815857.0
# 57     WI   5795483.0
# 58     WY    579315.0

# %% [markdown]
# ## We're going to want to merge the DataFrames on the two-letter abbreviation
# * This is called __`State`__ in the first data set so make sure the second dataset has the right column names

# %%
states.columns = ['State', 'Population']
states
# Out:
#    State  Population
# 0     AL   4874747.0
# 1     AK    739795.0
# 2     AS     51504.0
# 3     AZ   7016270.0
# 4     AR   3004279.0
# 5     CA  39536653.0
# 6     CO   5607154.0
# 7     CT   3588184.0
# 8     DE    961939.0
# 9     DC    693972.0
# 10    FM         NaN
# 11    FL  20984400.0
# 12    GA  10429379.0
# 13    GU    167358.0
# 14    HI   1427538.0
# 15    ID   1716943.0
# 16    IL  12802023.0
# 17    IN   6666818.0
# 18    IA   3145711.0
# 19    KS   2913123.0
# 20    KY   4454189.0
# 21    LA   4684333.0
# 22    ME   1335907.0
# 23    MH         NaN
# 24    MD   6052177.0
# 25    MA   6859819.0
# 26    MI   9962311.0
# 27    MN   5576606.0
# 28    MS   2984100.0
# 29    MO   6113532.0
# 30    MT   1050493.0
# 31    NE   1920076.0
# 32    NV   2998039.0
# 33    NH   1342795.0
# 34    NJ   9005644.0
# 35    NM   2088070.0
# 36    NY  19849399.0
# 37    NC  10273419.0
# 38    ND    755393.0
# 39    MP         NaN
# 40    OH  11658609.0
# 41    OK   3930864.0
# 42    OR   4142776.0
# 43    PW         NaN
# 44    PA  12805537.0
# 45    PR   3337177.0
# 46    RI   1059639.0
# 47    SC   5024369.0
# 48    SD    869666.0
# 49    TN   6715984.0
# 50    TX  28304596.0
# 51    UT   3101833.0
# 52    VT    623657.0
# 53    VI         NaN
# 54    VA   8470020.0
# 55    WA   7405743.0
# 56    WV   1815857.0
# 57    WI   5795483.0
# 58    WY    579315.0

# %% [markdown]
# ## Generate a new DataFrame that contains the number of  complaints per state and keeps track of those counts

# %%
complaints_by_state = data.groupby(['State']).size().reset_index(name='counts')

# %% [markdown]
# ## Merge the __`complaints_by_state`__ DataFrame and the states DataFrame on the __`State`__ column
# * Since there are U.S. territories in one of the datasets and not the other, we have some NaN results–get rid of those

# %%
merged = pd.merge(complaints_by_state, states, on='State').dropna()

# %% [markdown]
# ## Inspect the first few rows to ensure it worked properly

# %%
merged.head()
# Out:
#   State  counts  Population
# 0    AK    1056    739795.0
# 1    AL   10541   4874747.0
# 2    AR    4347   3004279.0
# 3    AS      25     51504.0
# 4    AZ   21077   7016270.0

# %% [markdown]
# ## Normalize the Population
# 1. Divide the counts column by the __`Population`__
# * Store the result in a new columnn called 'population_normalized'

# %%
merged['population_normalized'] = merged['counts'] / merged['Population']

# %% [markdown]
# ## Check out the first few rows of the data to make sure it looks like you expect

# %%
merged.head()
# Out:
#   State  counts  Population  population_normalized
# 0    AK    1056    739795.0               0.001427
# 1    AL   10541   4874747.0               0.002162
# 2    AR    4347   3004279.0               0.001447
# 3    AS      25     51504.0               0.000485
# 4    AZ   21077   7016270.0               0.003004

# %% [markdown]
# ## What are the top 10 states for complaints based upon raw counts?

# %%
merged.sort_values('counts', ascending=False)[:10]
# Out:
#    State  counts  Population  population_normalized
# 5     CA  135002  39536653.0               0.003415
# 10    FL   91133  20984400.0               0.004343
# 50    TX   76955  28304596.0               0.002719
# 39    NY   64340  19849399.0               0.003241
# 12    GA   47759  10429379.0               0.004579
# 36    NJ   36870   9005644.0               0.004094
# 17    IL   35988  12802023.0               0.002811
# 43    PA   33399  12805537.0               0.002608
# 52    VA   29547   8470020.0               0.003488
# 23    MD   29070   6052177.0               0.004803

# %% [markdown]
# ## What are the top 10 states for complaints normalized by population?

# %%
merged.sort_values('population_normalized', ascending=False)[:10]
# Out:
#    State  counts  Population  population_normalized
# 8     DC    5415    693972.0               0.007803
# 9     DE    4841    961939.0               0.005033
# 23    MD   29070   6052177.0               0.004803
# 12    GA   47759  10429379.0               0.004579
# 10    FL   91133  20984400.0               0.004343
# 36    NJ   36870   9005644.0               0.004094
# 38    NV   11734   2998039.0               0.003914
# 52    VA   29547   8470020.0               0.003488
# 5     CA  135002  39536653.0               0.003415
# 39    NY   64340  19849399.0               0.003241
